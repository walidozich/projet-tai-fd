# %% [markdown]
# # Projet TAI-FD - Segmentation d'Images\n\nCe notebook servira a l'exploration, aux visualisations, aux tests de segmentation et a la presentation progressive des resultats.\n\nApproche retenue : notebook pour l'analyse visuelle + modules Python dans `src/` pour les fonctions reutilisables.

# %% [markdown]
# ## Organisation des donnees\n\nFichiers detectes dans `dataset/` :\n\n- `Scene_1.png` avec `GT1.png`\n- `Scene_2.png` avec `GT2.png`\n- `Scene_3.png` avec `GT3.png`\n- `Scene_4_RGB_1.png` + `Scene_4_D_2.png` avec `GT4.png`

# %%
from pathlib import Path\n\nROOT = Path('..').resolve()\nDATASET_DIR = ROOT / 'dataset'\nOUTPUT_DIR = ROOT / 'outputs'\n\nprint('Dataset:', DATASET_DIR)\nprint('Outputs:', OUTPUT_DIR)
